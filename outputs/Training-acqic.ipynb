# %%
import lightgbm as lgb
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import mode
from sklearn.model_selection import ParameterGrid, train_test_split

# %%
seed = 1234
np.random.seed(seed)

# %% [markdown]
# ## Data Loading

# %%
DATA = pd.read_csv("data/proc_training_acqic.csv")
TEST_DATA = pd.read_csv("data/proc_testing_acqic.csv")

# %%
X = DATA.drop(columns='label')
y = DATA['label']

# %%
TEST_txkey = TEST_DATA['txkey']
X_test = TEST_DATA.drop(columns='txkey')

# %% [markdown]
# ## Model Construction

# %%
# model = lgb.LGBMClassifier(
#     boosting_type='gbdt',
#     objective='binary',
#     device='gpu',
#     random_state=seed,
# )
# model.set_params(
#     bagging_freq=1,
#     bagging_fraction=0.9,
#     feature_fraction=0.9,
#     # feval=lgb_f1_score,
#     # evals_result=eval_res,
# )

# %% [markdown]
# ## Training & Validation
# 先 grid search 找到不錯的參數，再去做 cross validation

# %%
cat_feats = [
    'contp',
    'etymd',
    'ecfg',
    # 'insfg',
    'bnsfg',
    'stscd',
    'ovrlt',
    'flbmk',
    'hcefg',
    'csmcu',
    'flg_3dsmk',
    # 'mcc_gp',
    # 'region_gp',
    # 'chid_gp'
]

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3)

# model.fit(
#     X_train, y_train,
#     categorical_feature=cat_feats,
#     callbacks=[lgb.early_stopping(5)],
#     eval_set=[(X_valid, y_valid)],
#     eval_metric=['binary_logloss'],
# )

# %%
params = {
    'num_leaves': range(45, 66, 2),
    'learning_rate': np.linspace(0.05, 0.15, 11),
    'n_estimators': [10],
    'min_split_gain': np.arange(0.005, 0.035, 0.005),
    'min_child_samples': range(10, 40, 10),
}
grid = ParameterGrid(params)
best_params = None
best_score = 100

for params in grid:
    model = lgb.LGBMClassifier(
        boosting_type='gbdt',
        objective='binary',
        device='gpu',
        random_state=seed,
        **params
    )
    
    model.fit(
        X_train, y_train,
        categorical_feature=cat_feats,
        callbacks=[lgb.early_stopping(5)],
        eval_set=[(X_valid, y_valid)],
        eval_metric=['binary_logloss'],
    )
    
    score = model.best_score_['valid_0']['binary_logloss']
    if score < best_score:
        best_score = score
        best_params = params
# Out:
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.036273 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00852804
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.034983 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00854298
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.034358 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00880584
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.032962 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00861142
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.032611 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00850722
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029531 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00867005
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.032481 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00859405
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029215 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00883665
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029329 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00873721
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029616 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00873648
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.032323 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00873588
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029102 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00852881
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029386 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00854295
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029345 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00880595
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.030034 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00861138
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029921 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00851964
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029686 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00865807
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029148 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00857985
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.030517 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00884788
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.030117 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.0086107
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.030755 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00873696
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.030306 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00873593
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029073 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.0085288
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.030082 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00854299
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.028970 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00880213
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029177 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00862257
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029079 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00851958
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029076 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00867004
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029301 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00862848
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029162 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.0088362
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.030275 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00861056
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029906 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.0087483
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.034985 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00873591
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029423 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.0085288
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029134 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00854295
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029351 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00880589
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029292 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00861142
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029157 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.0085084
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.035884 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00865884
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029254 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00862368
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029330 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00883617
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029023 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00861028
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.028647 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00873696
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.028983 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.0087359
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.028645 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.0085288
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029716 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00855414
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029023 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00883602
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029847 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00861141
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.028939 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00849464
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029051 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00867004
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029166 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00863954
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.028987 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00881492
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.029037 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00860991
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.028894 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00873643
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# ...
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0199158
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.038441 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0199623
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.039066 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0197813
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.031693 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0195993
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.032719 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0195685
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.034293 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0195434
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.033195 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0194064
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.039844 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0196783
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.031858 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0205296
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.034859 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.020352
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.039680 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0200984
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.033680 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0199158
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.032592 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0199623
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.032441 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0197813
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.031927 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0195993
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.045726 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0195685
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.039164 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0195434
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.032045 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0194064
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1626
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (69.60 MB) transferred to GPU in 0.032735 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0196783

# %%
print(f'Best Score: {best_score}')
print(f'Best Params: {best_params}')
# Out:
# Best Score: 0.008487853927811897
# Best Params: {'learning_rate': 0.05, 'min_child_samples': 10, 'min_split_gain': 0.030000000000000002, 'n_estimators': 10, 'num_leaves': 53}

# %%
# Found in the above grid search
# best_params = {
#     'learning_rate': 0.1,
#     'min_child_samples': 20,
#     'min_split_gain': 0.0001,
#     'n_estimators': 50,
#     'num_leaves': 51
# }

# %%
D_train = lgb.Dataset(X, y)

# %%
lgb_params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'device': 'gpu',
}
lgb_params.update(best_params)
eval_res = lgb.cv(
    lgb_params,
    D_train,
    nfold=5,
    metrics='binary_log_loss',
    categorical_feature=cat_feats,
    return_cvbooster=True
)
eval_res
# Out:
# /home/kuanhe/.cache/pypoetry/virtualenvs/esun-YNnw7uhi-py3.11/lib/python3.11/site-packages/lightgbm/engine.py:685: UserWarning: Found 'n_estimators' in params. Will use it instead of 'num_boost_round' argument
#   _log_warning(f"Found '{alias}' in params. Will use it instead of 'num_boost_round' argument")
# [LightGBM] [Info] Number of positive: 25623, number of negative: 6925197
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1635
# [LightGBM] [Info] Number of data points in the train set: 6950820, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (79.55 MB) transferred to GPU in 0.117586 secs. 1 sparse feature groups
# [LightGBM] [Info] Number of positive: 25624, number of negative: 6925197
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1635
# [LightGBM] [Info] Number of data points in the train set: 6950821, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (79.55 MB) transferred to GPU in 0.074307 secs. 1 sparse feature groups
# [LightGBM] [Info] Number of positive: 25623, number of negative: 6925198
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1635
# [LightGBM] [Info] Number of data points in the train set: 6950821, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (79.55 MB) transferred to GPU in 0.084279 secs. 1 sparse feature groups
# [LightGBM] [Info] Number of positive: 25623, number of negative: 6925198
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1635
# [LightGBM] [Info] Number of data points in the train set: 6950821, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (79.55 MB) transferred to GPU in 0.075573 secs. 1 sparse feature groups
# [LightGBM] [Info] Number of positive: 25623, number of negative: 6925198
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1635
# [LightGBM] [Info] Number of data points in the train set: 6950821, number of used features: 19
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (79.55 MB) transferred to GPU in 0.074751 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003686 -> initscore=-5.599431
# [LightGBM] [Info] Start training from score -5.599431
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003686 -> initscore=-5.599392
# [LightGBM] [Info] Start training from score -5.599392
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003686 -> initscore=-5.599432
# [LightGBM] [Info] Start training from score -5.599432
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003686 -> initscore=-5.599432
# [LightGBM] [Info] Start training from score -5.599432
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003686 -> initscore=-5.599432
# [LightGBM] [Info] Start training from score -5.599432
# {'cvbooster': <lightgbm.engine.CVBooster at 0x7f4ecbae19d0>}

# %%
models = eval_res['cvbooster']

# %%
outputs = models.predict(X_test)
preds = [np.where(outputs[i] < 0.5, 0, 1) for i in range(len(outputs))]
y_pred = mode(preds)[0]

res = {
    'txkey': TEST_txkey,
    'label': y_pred
}

pd.DataFrame(res).to_csv('preds.csv', index=False)

# %%
pd.Series(y_pred).value_counts()
# Out:
# 0    598701
# 1      1481
# Name: count, dtype: int64
