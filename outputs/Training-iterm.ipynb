# %%
import lightgbm as lgb
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import mode
from sklearn.model_selection import ParameterGrid, train_test_split

# %%
seed = 1234
np.random.seed(seed)

# %% [markdown]
# ## Data Loading

# %%
DATA = pd.read_csv("data/proc_training_iterm.csv")
TEST_DATA = pd.read_csv("data/proc_testing_iterm.csv")

# %%
X = DATA.drop(columns='label')
y = DATA['label']

# %%
TEST_txkey = TEST_DATA['txkey']
X_test = TEST_DATA.drop(columns='txkey')

# %% [markdown]
# ## Model Construction

# %%
# model = lgb.LGBMClassifier(
#     boosting_type='gbdt',
#     objective='binary',
#     device='gpu',
#     random_state=seed,
# )
# model.set_params(
#     bagging_freq=1,
#     bagging_fraction=0.9,
#     feature_fraction=0.9,
#     # feval=lgb_f1_score,
#     # evals_result=eval_res,
# )

# %% [markdown]
# ## Training & Validation
# 先 grid search 找到不錯的參數，再去做 cross validation

# %%
cat_feats = [
    'contp',
    'etymd',
    'ecfg',
    # 'insfg',
    'bnsfg',
    'stscd',
    'ovrlt',
    'flbmk',
    'hcefg',
    'csmcu',
    'flg_3dsmk',
    # 'mcc_gp',
    # 'region_gp',
    # 'chid_gp'
]

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3)

# model.fit(
#     X_train, y_train,
#     categorical_feature=cat_feats,
#     callbacks=[lgb.early_stopping(5)],
#     eval_set=[(X_valid, y_valid)],
#     eval_metric=['binary_logloss'],
# )

# %%
params = {
    'num_leaves': range(45, 66, 2),
    'learning_rate': np.linspace(0.05, 0.15, 11),
    'n_estimators': [10],
    'min_split_gain': np.arange(0.00005, 0.00035, 0.00005),
    'min_child_samples': range(10, 40, 10),
}
grid = ParameterGrid(params)
best_params = None
best_score = 100

for params in grid:
    model = lgb.LGBMClassifier(
        boosting_type='gbdt',
        objective='binary',
        device='gpu',
        random_state=seed,
        **params
    )
    
    model.fit(
        X_train, y_train,
        categorical_feature=cat_feats,
        callbacks=[lgb.early_stopping(5)],
        eval_set=[(X_valid, y_valid)],
        eval_metric=['binary_logloss'],
    )
    
    score = model.best_score_['valid_0']['binary_logloss']
    if score < best_score:
        best_score = score
        best_params = params
# Out:
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.041458 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00843985
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.048754 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00842435
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.042883 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00849707
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.031359 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00860653
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.029241 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00859407
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.029766 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00863644
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.046141 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00863866
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.039133 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00859469
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.050958 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.0086504
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.051495 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00863083
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.054938 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00853744
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.043315 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00844781
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.043996 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00842434
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.055969 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00849647
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.046278 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00860653
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.044198 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00859407
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.047455 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.0086232
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.051168 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00863865
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.063607 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00859472
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.046371 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00864745
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.051849 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00863083
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.054341 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00850515
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.042033 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00843984
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.033713 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00842453
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.055356 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00849647
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.046920 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00860476
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.058644 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00859404
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.041810 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00863644
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.059986 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00863864
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.045302 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00859469
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.047219 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00865615
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.055925 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00863082
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.053522 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00853744
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.043001 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00843985
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.057232 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00842436
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.051076 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.0084964
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.065381 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00860652
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.068245 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00859407
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.043357 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00860995
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.046633 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00863865
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.030780 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00859623
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.039853 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00865615
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.043921 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00863082
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.030148 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00850515
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.030268 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00843984
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.030996 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00842435
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.028954 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.0084964
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.028466 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00860476
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.032020 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00859407
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.029489 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.0086232
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.042048 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00863866
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.042073 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00859491
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.057708 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00865615
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.057714 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's binary_logloss: 0.00863083
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# ...
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0196532
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.031186 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0195152
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.026993 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0193981
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.027590 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0193494
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.026867 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0192612
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.027028 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0194696
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.026821 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0190904
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.026996 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0191052
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.027770 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0197657
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.033851 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.019634
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.027715 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0194553
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.027693 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0196532
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.027839 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0195152
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.027835 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0193981
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.027691 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0193494
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.027655 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0192612
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.027820 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0194696
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.027845 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0190904
# [LightGBM] [Info] Number of positive: 22383, number of negative: 6059585
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1432
# [LightGBM] [Info] Number of data points in the train set: 6081968, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (46.40 MB) transferred to GPU in 0.027709 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003680 -> initscore=-5.601095
# [LightGBM] [Info] Start training from score -5.601095
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0191052

# %%
print(f'Best Score: {best_score}')
print(f'Best Params: {best_params}')
# Out:
# Best Score: 0.008372119958856715
# Best Params: {'learning_rate': 0.05, 'min_child_samples': 20, 'min_split_gain': 0.0002, 'n_estimators': 10, 'num_leaves': 63}

# %%
# Found in the above grid search
# best_params = {
#     'learning_rate': 0.1,
#     'min_child_samples': 20,
#     'min_split_gain': 0.0001,
#     'n_estimators': 50,
#     'num_leaves': 51
# }

# %%
D_train = lgb.Dataset(X, y)

# %%
lgb_params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'device': 'gpu',
}
lgb_params.update(best_params)
eval_res = lgb.cv(
    lgb_params,
    D_train,
    nfold=5,
    metrics='binary_log_loss',
    categorical_feature=cat_feats,
    return_cvbooster=True
)
eval_res
# Out:
# /home/kuanhe/.cache/pypoetry/virtualenvs/esun-YNnw7uhi-py3.11/lib/python3.11/site-packages/lightgbm/engine.py:685: UserWarning: Found 'n_estimators' in params. Will use it instead of 'num_boost_round' argument
#   _log_warning(f"Found '{alias}' in params. Will use it instead of 'num_boost_round' argument")
# [LightGBM] [Info] Number of positive: 25623, number of negative: 6925197
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1442
# [LightGBM] [Info] Number of data points in the train set: 6950820, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (53.03 MB) transferred to GPU in 0.043017 secs. 1 sparse feature groups
# [LightGBM] [Info] Number of positive: 25624, number of negative: 6925197
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1442
# [LightGBM] [Info] Number of data points in the train set: 6950821, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (53.03 MB) transferred to GPU in 0.043244 secs. 1 sparse feature groups
# [LightGBM] [Info] Number of positive: 25623, number of negative: 6925198
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1442
# [LightGBM] [Info] Number of data points in the train set: 6950821, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (53.03 MB) transferred to GPU in 0.041913 secs. 1 sparse feature groups
# [LightGBM] [Info] Number of positive: 25623, number of negative: 6925198
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1442
# [LightGBM] [Info] Number of data points in the train set: 6950821, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (53.03 MB) transferred to GPU in 0.042306 secs. 1 sparse feature groups
# [LightGBM] [Info] Number of positive: 25623, number of negative: 6925198
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1442
# [LightGBM] [Info] Number of data points in the train set: 6950821, number of used features: 18
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4090, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 8 dense feature groups (53.03 MB) transferred to GPU in 0.042775 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003686 -> initscore=-5.599431
# [LightGBM] [Info] Start training from score -5.599431
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003686 -> initscore=-5.599392
# [LightGBM] [Info] Start training from score -5.599392
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003686 -> initscore=-5.599432
# [LightGBM] [Info] Start training from score -5.599432
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003686 -> initscore=-5.599432
# [LightGBM] [Info] Start training from score -5.599432
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003686 -> initscore=-5.599432
# [LightGBM] [Info] Start training from score -5.599432
# {'cvbooster': <lightgbm.engine.CVBooster at 0x7fafcfb3dfd0>}

# %%
models = eval_res['cvbooster']

# %%
outputs = models.predict(X_test)
preds = [np.where(outputs[i] < 0.5, 0, 1) for i in range(len(outputs))]
y_pred = mode(preds)[0]

res = {
    'txkey': TEST_txkey,
    'label': y_pred
}

pd.DataFrame(res).to_csv('preds_iterm.csv', index=False)

# %%
pd.Series(y_pred).value_counts()
# Out:
# 0    598698
# 1      1484
# Name: count, dtype: int64
